# %% [markdown]
# ## Handling Duplicated Data

# %%
import pandas as pd

# %% [markdown]
# ## Primer

# %%
# Create a sample DataFrame with duplicated rows
df = pd.DataFrame(
    {
        "Name": ["John", "Rock", "Neil", "Tom", "John", "John"],
        "Rank": [1, 2, 3, 6, 1, 1],
        "Marks": [98, 59, 97, 99, 98, 98],
    }
)
display(df)
# Out:
#    Name  Rank  Marks
# 0  John     1     98
# 1  Rock     2     59
# 2  Neil     3     97
# 3   Tom     6     99
# 4  John     1     98
# 5  John     1     98

# %%
# Identify duplicated rows, keeping the first occurrence
df.duplicated(keep="first")
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# dtype: bool

# %%
# Identify duplicated rows, keeping the last occurrence
df.duplicated(keep="last")
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
# Count total number of duplicated rows
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
# Display duplicated rows
# Note: we use boolean indexing to filter the DataFrame. We will learn more about this in the next lesson.
df[df.duplicated()]
# Out:
#    Name  Rank  Marks
# 4  John     1     98
# 5  John     1     98

# %%
# Remove duplicated rows, keeping the first occurrence
df.drop_duplicates(keep="first")
# Out:
#    Name  Rank  Marks
# 0  John     1     98
# 1  Rock     2     59
# 2  Neil     3     97
# 3   Tom     6     99

# %%
# Remove duplicated rows, keeping the last occurrence
df.drop_duplicates(keep="last")
# Out:
#    Name  Rank  Marks
# 1  Rock     2     59
# 2  Neil     3     97
# 3   Tom     6     99
# 5  John     1     98

# %% [markdown]
# ## Real Data

# %%
# Load the Adult dataset
adult = pd.read_csv("./data/adult.csv")

# %%
# Display the first few rows of the dataset
display(adult.head())
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   24    Private  369667  Some-college               10       Never-married
# 4   44    Private  160323  Some-college               10  Married-civ-spouse
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3      Other-service    Unmarried  White  Female             0             0
# 4  Machine-op-inspct      Husband  Black    Male          7688             0
#
#    hours-per-week native-country income
# ...

# %%
# Display dataset information
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3246 entries, 0 to 3245
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              3246 non-null   int64
#  1   workclass        3246 non-null   object
#  2   fnlwgt           3246 non-null   int64
#  3   education        3246 non-null   object
#  4   educational-num  3246 non-null   int64
#  5   marital-status   3246 non-null   object
#  6   occupation       3246 non-null   object
#  7   relationship     3246 non-null   object
#  8   race             3246 non-null   object
#  9   gender           3246 non-null   object
#  10  capital-gain     3246 non-null   int64
#  11  capital-loss     3246 non-null   int64
#  12  hours-per-week   3246 non-null   int64
#  13  native-country   3246 non-null   object
#  14  income           3246 non-null   object
# dtypes: int64(6), object(9)
# memory usage: 380.5+ KB

# %%
print(adult.isnull().sum())
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
# Identify duplicated rows in the Adult dataset
adult.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3241    False
# 3242    False
# 3243    False
# 3244    False
# 3245    False
# Length: 3246, dtype: bool

# %%
# Count total number of duplicated rows in the Adult dataset
print(adult.duplicated().sum())
# Out:
# 9

# %%
# Display duplicated rows in the Adult dataset
adult[adult.duplicated()]
# Out:
#       age         workclass  fnlwgt     education  educational-num  \
# 9      24           Private  369667  Some-college               10
# 27     45  Self-emp-not-inc  432824       HS-grad                9
# 53     18           Private   54440  Some-college               10
# 867    24           Private  194630     Bachelors               13
# 2528   48           Private   56071     Bachelors               13
# 2687   41           Private  319271  Some-college               10
# 2794   25           Private  199143       HS-grad                9
# 2884   22           Private  333838       HS-grad                9
# 3076   44           Private  141131          12th                8
#
#           marital-status         occupation   relationship  \
# 9          Never-married      Other-service      Unmarried
# 27    Married-civ-spouse       Craft-repair        Husband
# 53         Never-married      Other-service      Own-child
# ...

# %%
# Remove duplicated rows, keeping the first occurrence
adult.drop_duplicates(keep="first")
# Out:
#       age  workclass  fnlwgt     education  educational-num  \
# 0      25    Private  226802          11th                7
# 1      38    Private   89814       HS-grad                9
# 2      28  Local-gov  336951    Assoc-acdm               12
# 3      24    Private  369667  Some-college               10
# 4      44    Private  160323  Some-college               10
# ...   ...        ...     ...           ...              ...
# 3241   18    Private  161245          11th                7
# 3242   32    Private  262024       HS-grad                9
# 3243   21    Private  287681       HS-grad                9
# 3244   27    Private  303601          12th                8
# 3245   58          ?  365410  Some-college               10
#
#           marital-status         occupation    relationship   race  gender  \
# 0          Never-married  Machine-op-inspct       Own-child  Black    Male
# 1     Married-civ-spouse    Farming-fishing         Husband  White    Male
# ...

# %%
# Display the shape of the original and cleaned datasets
print(f"The shape of the original dataset: {adult.shape}")
print("-"*50)
clean_adult = adult.drop_duplicates(keep="first")
print(f"The shape of the cleaned dataset: {clean_adult.shape}")
# Out:
# The shape of the original dataset: (3246, 15)
# --------------------------------------------------
# The shape of the cleaned dataset: (3237, 15)

# %%
# Remove duplicates based on specific columns: "age" and "workclass"
adult.drop_duplicates(subset=["age", "workclass"])
# Out:
#       age     workclass  fnlwgt     education  educational-num  \
# 0      25       Private  226802          11th                7
# 1      38       Private   89814       HS-grad                9
# 2      28     Local-gov  336951    Assoc-acdm               12
# 3      24       Private  369667  Some-college               10
# 4      44       Private  160323  Some-college               10
# ...   ...           ...     ...           ...              ...
# 2778   20  Self-emp-inc  154782       HS-grad                9
# 2820   63   Federal-gov  160473       HS-grad                9
# 2964   19   Without-pay   43627       HS-grad                9
# 3145   66     Local-gov  154171  Some-college               10
# 3185   74   Without-pay  216001       7th-8th                4
#
#           marital-status         occupation   relationship   race  gender  \
# 0          Never-married  Machine-op-inspct      Own-child  Black    Male
# ...
